# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
sns.set(style="ticks", color_codes=True)
# %matplotlib inline

# %% [markdown]
# # Load and Clean Data

# %%
# read the csv file
df = pd.read_csv('sentiment.csv')
print(df.shape)
# Out:
# (463136, 4)

# %%
# delete null row
df.dropna(how='any',inplace=True)
print(df.shape)
# Out:
# (463044, 4)

# %%
# find unusual rows
def set_as_nan(x):
    if x == 'time':
        return np.nan
    else:
        return x
df['time'] = df['time'].map(set_as_nan)

# %%
# delete unusual rows
df.dropna(how='any',inplace=True)
print(df.shape)
# Out:
# (463037, 4)

# %%
# select columns
df = df[['time','score','magnitude']]

# %%
df['score'] = df['score'].map(lambda x:float(x))
df['magnitude'] = df['magnitude'].map(lambda x:float(x))
df['sentiment'] = df['score'] * df['magnitude']

# %%
df = pd.DataFrame(df.groupby(['time'])['score','magnitude','sentiment'].mean())
df = df.reset_index()
df = df.sort_values('time')

# %%
df1 = pd.read_csv('hot.csv')
df2 = pd.read_csv('bitcoinprice.csv')
df1 = df1.sort_values(by='date')
df1.columns = ['time','googleview']
df2 = df2.sort_values(by='time')
df2.columns = ['time','price']
df1 = df1.reset_index()
df1 = df1[['time','googleview']]

# %%
df = df.merge(df1,how='inner',on='time')
df = df.merge(df2,how='inner',on='time')

# %% [markdown]
# # Day as Grain

# %%
df.head()
# Out:
#          time     score  magnitude  sentiment  googleview  price
# 0  2013-01-01  0.225000   0.334615   0.145577          43   13.3
# 1  2013-01-02  0.045455   0.321212   0.014242          72   13.3
# 2  2013-01-03  0.057692   0.475000   0.025192          24   13.4
# 3  2013-01-04  0.067273   0.340000   0.035091          26   13.5
# 4  2013-01-05 -0.002083   0.347917  -0.016458          91   13.4

# %%
pairp = sns.pairplot(df[['score','magnitude','sentiment','googleview','price']],
                     kind='reg',
                     plot_kws={'line_kws':{'color':'red'}},
                     x_vars=["score", "magnitude",'sentiment',"googleview"],
                     y_vars=["price"])

# %%
df.columns = ['date','score','magnitude','sentiment','googleview','price']

# %%
df.head()
# Out:
#          date     score  magnitude  sentiment  googleview  price
# 0  2013-01-01  0.225000   0.334615   0.145577          43   13.3
# 1  2013-01-02  0.045455   0.321212   0.014242          72   13.3
# 2  2013-01-03  0.057692   0.475000   0.025192          24   13.4
# 3  2013-01-04  0.067273   0.340000   0.035091          26   13.5
# 4  2013-01-05 -0.002083   0.347917  -0.016458          91   13.4

# %% [markdown]
# # Month as Grain

# %%
df['month'] = df['date'].map(lambda x:x[5:7])

# %%
df['year'] = df['date'].map(lambda x:x[0:4])

# %%
df['day'] = df['date'].map(lambda x:x[8:11])

# %%
df = df[['year','month','day','score','magnitude','sentiment','googleview','price']]

# %%
gdf = pd.DataFrame(df.groupby(['year','month'])['score','magnitude','sentiment','googleview','price'].mean()).reset_index()

# %%
pairp = sns.pairplot(gdf[['score','magnitude','sentiment','googleview','price']],
                     kind='reg',
                     plot_kws={'line_kws':{'color':'red'}},
                     x_vars=["score", "magnitude",'sentiment',"googleview"],
                     y_vars=["price"])

# %% [markdown]
# # Lagging Insight

# %%
# lagged function
def lag(data,n=1):
    data = list(data)
    lagged_data = [data[i] for i in range(n,len(data))]
    for i in range(0,n):
        lagged_data.append(np.nan)
    return pd.Series(lagged_data)

# %%
gdf['sentiment_lag1'] = lag(gdf['sentiment'])
gdf['score_lag1'] = lag(gdf['score'])
gdf['magnitude_lag1'] = lag(gdf['magnitude'])
gdf['googleview_lag1'] = lag(gdf['googleview'])

gdf['sentiment_lag2'] = lag(gdf['sentiment'],2)
gdf['score_lag2'] = lag(gdf['score'],2)
gdf['magnitude_lag2'] = lag(gdf['magnitude'],2)
gdf['googleview_lag2'] = lag(gdf['googleview'],2)

gdf['sentiment_lag3'] = lag(gdf['sentiment'],3)
gdf['score_lag3'] = lag(gdf['score'],3)
gdf['magnitude_lag3'] = lag(gdf['magnitude'],3)
gdf['googleview_lag3'] = lag(gdf['googleview'],3)

# %%
pairp = sns.pairplot(gdf[list(gdf.columns[2:])],
                     kind='reg',
                     plot_kws={'line_kws': {'color': 'red'}},
                     x_vars=['score',
                             'score_lag1',
                             'score_lag2',
                             'score_lag3',],
                     y_vars=["price"])

# %%
pairp = sns.pairplot(gdf[list(gdf.columns[2:])],
                     kind='reg',
                     plot_kws={'line_kws': {'color': 'red'}},
                     x_vars=['magnitude',
                             'magnitude_lag1',
                             'magnitude_lag2',
                             'magnitude_lag3'],
                     y_vars=["price"])

# %%
pairp = sns.pairplot(gdf[list(gdf.columns[2:])],
                     kind='reg',
                     plot_kws={'line_kws': {'color': 'red'}},
                     x_vars=['sentiment',
                             'sentiment_lag1',
                             'sentiment_lag2',
                             'sentiment_lag3'],
                     y_vars=["price"])

# %%
pairp = sns.pairplot(gdf[list(gdf.columns[2:])],
                     kind='reg',
                     plot_kws={'line_kws': {'color': 'red'}},
                     x_vars=['googleview',
                             'googleview_lag1',
                             'googleview_lag2',
                             'googleview_lag3'],
                     y_vars=["price"])

# %% [markdown]
# # Multiple Variable Regression

# %%
gdf=gdf.dropna()
reg=LinearRegression().fit(gdf[['sentiment_lag1','score_lag1','magnitude_lag1','googleview_lag1']],gdf[['price']])
print("Lag One Regression")
reg.score(gdf[['sentiment_lag1','score_lag1','magnitude_lag1','googleview_lag1']],gdf[['price']])

# %%
for i in range(0,4):
    if i==0:
        reg=LinearRegression().fit(gdf[['sentiment','score','magnitude','googleview']],gdf[['price']])
        print("Current Variable Regression")
        score = reg.score(gdf[['sentiment','score','magnitude','googleview']],gdf[['price']])
    else:
        reg=LinearRegression().fit(gdf[['sentiment_lag'+str(i),'score_lag'+str(i),
                                        'magnitude_lag'+str(i),'googleview_lag'+str(i)]],gdf[['price']])
        print("Lag "+str(i)+" Variable Regression")
        score = reg.score(gdf[['sentiment_lag'+str(i),
                       'score_lag'+str(i),      
                       'magnitude_lag'+str(i),
                       'googleview_lag'+str(i)]],gdf[['price']])
    print('Score: %.2f' % score )
# Out:
# Current Variable Regression
# Score: 0.80
# Lag 1 Variable Regression
# Score: 0.87
# Lag 2 Variable Regression
# Score: 0.83
# Lag 3 Variable Regression
# Score: 0.79

# %% [markdown]
# # Application

# %%
1. 爬虫运行
